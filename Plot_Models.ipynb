# %% [markdown]
# ## Plotting Model Architectures

# %% [markdown]
# ### Importing Libraries

# %%
import torch
import models
from torchview import draw_graph

# %% [markdown]
# ### FeatureExtractor

# %%
Model = models.Classifier(input_features=512)

model_graph = draw_graph(Model, input_data=torch.randn(1,512), device='cuda')
model_graph.visual_graph
